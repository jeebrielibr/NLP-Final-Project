# %% [markdown]
# Load Dataset

# %%
import pandas as pd

df = pd.read_csv("../Dataset/Dataset_kotor.csv")

print(df.head())
print(df.shape)
print(df['label'].value_counts())
# Out:
#                                                 text  label
# 0                                 assalamu'alaikum..      0
# 1                                  wa'alaikumussalam      0
# 2                             udah lewat 22 menit ni      0
# 3                                          16:30 wib      0
# 4  Tribun Tv Mana Ini Kenapa Acaranya Belum Dimul...      0
# (16580, 2)
# label
# 0    9184
# 1    7396
# Name: count, dtype: int64

# %% [markdown]
# Cek Dataset

# %%
print(df.shape)
# Out:
# (16580, 2)

# %%
print(df['label'].value_counts())
# Out:
# label
# 0    9184
# 1    7396
# Name: count, dtype: int64

# %%
print(df.isnull().sum())
# Out:
# text     0
# label    0
# dtype: int64

# %% [markdown]
# Data Cleaning

# %%
print(df.columns)
# Out:
# Index(['text', 'label'], dtype='str')

# %%
#cleaning the text data
import re

def clean_text(text):
    text = str(text).lower()

    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"www\S+", "", text)

    text = re.sub(r"@\w+", "", text)

    text = re.sub(r"#\w+", "", text)

    text = re.sub(r"[^a-zA-Z\s]", " ", text)

    text = re.sub(r"\s+", " ", text).strip()

    return text

df['text'] = df['text'].apply(clean_text)

# %%
for i in range(10):
    print(df['text'].iloc[i])
# Out:
# assalamu alaikum
# wa alaikumussalam
# udah lewat menit ni
# wib
# tribun tv mana ini kenapa acaranya belum dimulai ini wayang jogja night carnival
# saya nonton apa ini tribun tv kenapa acara wayang tribun night carnival tak kunjung dimulai
# kapan mulainya min pengen keburu nonton
# assalamu alaikum
# lama
# ini nanti bakal live disini taa

# %%
print(df.isnull().sum())
# Out:
# text     0
# label    0
# dtype: int64

# %%
print("Jumlah data setelah cleaning:", len(df))
# Out:
# Jumlah data setelah cleaning: 16580

# %% [markdown]
# Smpan Dataset

# %%
df[['text','label']].to_csv(
    "dataset_clean_final.csv",
    index=False
)

print("Dataset berhasil disimpan")
# Out:
# Dataset berhasil disimpan

# %% [markdown]
# Encode Label

# %%
print(df['label'].unique())
# Out:
# [0 1]

# %%
print(df['label'].value_counts())
# Out:
# label
# 0    9184
# 1    7396
# Name: count, dtype: int64

# %% [markdown]
# Split Data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df['text'],
    df['label'],
    test_size=0.2,
    random_state=42,
    stratify=df['label']
)

print("Train :", len(X_train))
print("Test  :", len(X_test))
# Out:
# Train : 13264
# Test  : 3316

# %%
# cek distribusi label pada data train dan test
print("Train")
print(y_train.value_counts())

print("\nTest")
print(y_test.value_counts())
# Out:
# Train
# label
# 0    7347
# 1    5917
# Name: count, dtype: int64
#
# Test
# label
# 0    1837
# 1    1479
# Name: count, dtype: int64
